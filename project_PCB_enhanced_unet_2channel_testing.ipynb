# %%
import os, cv2
import numpy as np
import matplotlib.pyplot as plt
from keras.models import load_model
# Out:
# 2024-04-23 20:44:13.585421: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-04-23 20:44:13.589736: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-04-23 20:44:13.644920: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-23 20:44:14.818214: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
cwd = f"{os.getcwd()}/"
img_path = f"{cwd}data/Images/"
pm_path = f"{cwd}data/Pixel_masks/"

# %%
model = load_model('model_unet_trained_on_2x100.keras')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 model = load_model('model_unet_trained_on_2x100.keras')
#
# File ~/.pypoetry/virtualenvs/modules-CDq79-GH-py3.9/lib/python3.9/site-packages/keras/src/saving/saving_api.py:176, in load_model(filepath, custom_objects, compile, safe_mode)
#     173         is_keras_zip = True
#     175 if is_keras_zip:
# --> 176     return saving_lib.load_model(
#     177         filepath,
#     178         custom_objects=custom_objects,
#     179         compile=compile,
#     180         safe_mode=safe_mode,
#     181     )
#     182 if str(filepath).endswith((".h5", ".hdf5")):
#     183     return legacy_h5_format.load_model_from_hdf5(filepath)
#
# File ~/.pypoetry/virtualenvs/modules-CDq79-GH-py3.9/lib/python3.9/site-packages/keras/src/saving/saving_lib.py:155, in load_model(filepath, custom_objects, compile, safe_mode)
#     153 # Construct the model from the configuration file in the archive.
#     154 with ObjectSharingScope():
# --> 155     model = deserialize_keras_object(
#     156         config_dict, custom_objects, safe_mode=safe_mode
#     157     )
#     159 all_filenames = zf.namelist()
#     160 if _VARS_FNAME + ".h5" in all_filenames:
#
# File ~/.pypoetry/virtualenvs/modules-CDq79-GH-py3.9/lib/python3.9/site-packages/keras/src/saving/serialization_lib.py:727, in deserialize_keras_object(config, custom_objects, safe_mode, **kwargs)
#     725     compile_config = config.get("compile_config", None)
#     726     if compile_config:
# --> 727         instance.compile_from_config(compile_config)
#     728         instance.compiled = True
#     730 if "shared_object_id" in config:
#
# File ~/.pypoetry/virtualenvs/modules-CDq79-GH-py3.9/lib/python3.9/site-packages/keras/src/trainers/trainer.py:834, in Trainer.compile_from_config(self, config)
#     823     warnings.warn(
#     824         "`compile()` was not called as part of model loading "
#     825         "because the model's `compile()` method is custom. "
#    (...)
#     831         stacklevel=2,
#     832     )
#     833     return
# --> 834 config = serialization_lib.deserialize_keras_object(config)
#     835 self.compile(**config)
#     836 if hasattr(self, "optimizer") and self.built:
#     837     # Create optimizer variables.
#
# File ~/.pypoetry/virtualenvs/modules-CDq79-GH-py3.9/lib/python3.9/site-packages/keras/src/saving/serialization_lib.py:589, in deserialize_keras_object(config, custom_objects, safe_mode, **kwargs)
#     586     raise TypeError(f"Could not parse config: {config}")
#     588 if "class_name" not in config or "config" not in config:
# --> 589     return {
#     590         key: deserialize_keras_object(
#     591             value, custom_objects=custom_objects, safe_mode=safe_mode
#     592         )
#     593         for key, value in config.items()
#     594     }
#     596 class_name = config["class_name"]
#     597 inner_config = config["config"] or {}
#
# File ~/.pypoetry/virtualenvs/modules-CDq79-GH-py3.9/lib/python3.9/site-packages/keras/src/saving/serialization_lib.py:590, in <dictcomp>(.0)
#     586     raise TypeError(f"Could not parse config: {config}")
#     588 if "class_name" not in config or "config" not in config:
#     589     return {
# --> 590         key: deserialize_keras_object(
#     591             value, custom_objects=custom_objects, safe_mode=safe_mode
#     592         )
#     593         for key, value in config.items()
#     594     }
#     596 class_name = config["class_name"]
#     597 inner_config = config["config"] or {}
#
# File ~/.pypoetry/virtualenvs/modules-CDq79-GH-py3.9/lib/python3.9/site-packages/keras/src/saving/serialization_lib.py:671, in deserialize_keras_object(config, custom_objects, safe_mode, **kwargs)
#     669 if class_name == "function":
#     670     fn_name = inner_config
# --> 671     return _retrieve_class_or_fn(
#     672         fn_name,
#     673         registered_name,
#     674         module,
#     675         obj_type="function",
#     676         full_config=config,
#     677         custom_objects=custom_objects,
#     678     )
#     680 # Below, handling of all classes.
#     681 # First, is it a shared object?
#     682 if "shared_object_id" in config:
#
# File ~/.pypoetry/virtualenvs/modules-CDq79-GH-py3.9/lib/python3.9/site-packages/keras/src/saving/serialization_lib.py:805, in _retrieve_class_or_fn(name, registered_name, module, obj_type, full_config, custom_objects)
#     802     if obj is not None:
#     803         return obj
# --> 805 raise TypeError(
#     806     f"Could not locate {obj_type} '{name}'. "
#     807     "Make sure custom classes are decorated with "
#     808     "`@keras.saving.register_keras_serializable()`. "
#     809     f"Full object config: {full_config}"
#     810 )
#
# TypeError: Could not locate function 'combined_loss'. Make sure custom classes are decorated with `@keras.saving.register_keras_serializable()`. Full object config: {'module': 'builtins', 'class_name': 'function', 'config': 'combined_loss', 'registered_name': 'function'}

# %%
#np.random.seed(666)

rnd_file_names = np.random.choice(os.listdir(img_path), size=5)

for file_name in rnd_file_names:
    img = cv2.imread(f"{img_path}{file_name}")
    img = cv2.resize(img, (600,600))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    pm = cv2.imread(f"{pm_path}pm-{os.path.splitext(file_name)[0]}.png")
    pm = cv2.resize(pm, (600, 600))
    pm = cv2.cvtColor(pm, cv2.COLOR_BGR2GRAY)
    
    new_size = (100, 100)

    cropped_images = []
    cropped_masks = []
    cropped_class = []

    for y in range(0, 600, 100):
        for x in range(0, 600, 100):
            y0, x0 = y, x
            y100, x100 = y+100, x+100
            # if a bounding box crosses the cropping border, increase shift the corresponding border, so defects are not cut off
            while( np.any(pm[y0, x0:x100])) and (y0 != 0): 
                y0 -= 1
            while (np.any(pm[min(y100, 599), x0:x100])) and (y100 != 600):
                y100 += 1
            while( np.any(pm[y0:y100, x0])) and (x0 != 0):
                x0 -= 1
            while( np.any(pm[y0:y100, min(x100, 599)])) and (x100 != 600):
                x100 += 1
            img_patch = cv2.resize(img[y0:y100, x0:x100], (100, 100))
            pm_patch = cv2.resize(pm[y0:y100, x0:x100], (100, 100))
            if np.any(pm_patch):
                cropped_images.append(img_patch)
                cropped_masks.append(pm_patch)
                cropped_class.append(file_name)

    cropped_images = np.array(cropped_images)
    cropped_masks = np.array(cropped_masks)
    cropped_class = np.array(cropped_class)

    predictions = []
    predictions_rect = []

    for img_patch in cropped_images:
        img_4_pred = np.asarray(img_patch) / 255.0
        img_4_pred = np.expand_dims(img_4_pred, axis=0)
        pred = model.predict(img_4_pred)
        pred = pred * 255
        pred = pred.astype(np.uint8)
        pred = pred.squeeze()
        predictions.append(pred)

        _, pred_thresh = cv2.threshold(pred , 200, 255, type=cv2.THRESH_BINARY)
        cnt, hier = cv2.findContours(pred_thresh, mode=cv2.RETR_EXTERNAL, method=cv2.CHAIN_APPROX_SIMPLE)


        

        pred_rect = pred.copy()
        
        scale = 1.5
        for c in cnt:
            x, y, w, h = cv2.boundingRect(c)
            # Calculate new coordinates to extend the rectangle by 50%
            x50 = max(0, x - int(w * (scale-1)/2))  # 25% of width
            y50 = max(0, y - int(h * (scale-1)/2))  # 25% of height
            w50 = min(pred_rect.shape[1] - x50, int(w * scale))  # 50% increase in width
            h50 = min(pred_rect.shape[0] - y50, int(h * scale))  # 50% increase in height
            cv2.rectangle(pred_rect, (x50, y50), (x50+w50, y50+h50), 255, -1)
        
        predictions_rect.append(pred_rect)
        

    predictions = np.asarray(predictions)
    predictions_rect = np.asarray(predictions_rect)
    n = predictions.shape[0]

    fig, ax = plt.subplots(1, 3*n, figsize=(15*n, 15))
    for i, img, pm, pr in zip(range(len(ax)), cropped_images, cropped_masks, predictions_rect):
        ax[3*i].imshow(img, cmap='gray')
        ax[3*i].axis('off')
        ax[3*i+1].imshow(pm, cmap='gray')
        ax[3*i+1].axis('off')
        ax[3*i+2].imshow(pr, cmap='gray')
        ax[3*i+2].axis('off')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
